# %% [markdown]
# # Portfolio Optimization using Deep Reinforcement Learning
# ----

# %% [markdown]
# ## 3.0 Stock Selection
# ---
# Auto Encoders are employed to select the less volatile stocks by choosing stocks with less reconstruction error. These are the stocks that are included in the portfolio

# %% [markdown]
# ### 3.1 Import Relevant Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras

# %%
from numpy import array
from keras.models import Model
from keras.layers import Input
from keras.layers import LSTM
from keras.layers import Dense, Activation
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.utils import plot_model
from keras import regularizers, optimizers

from sklearn import preprocessing

# %% [markdown]
# ### 3.2 Load the Data

# %%
# Load the close prices dataset
prices_data = pd.read_csv('./datasets/close_prices.csv')

# %%
df = prices_data.copy()

# %%
df = df.reset_index(drop=True).set_index(['date'])

# %%
df.head()
# Out:
#             HCLTECH.NS  EICHERMOT.NS  HINDALCO.NS  INDUSINDBK.NS   GRASIM.NS  \
# date
# 2008-01-01   83.612503     41.000000   197.665359     131.000000  589.437805
# 2008-01-02   81.474998     41.000000   199.115448     132.199997  590.209290
# 2008-01-03   79.187500     46.200001   200.656158     131.399994  580.951111
# 2008-01-04   79.237503     43.500000   200.203018     135.000000  563.823486
# 2008-01-07   79.000000     42.400002   198.481033     134.500000  559.194397
#
#             AXISBANK.NS     ONGC.NS  BRITANNIA.NS    BPCL.NS  RELIANCE.NS  \
# date
# 2008-01-01   196.690002  209.149994    149.000000  88.283333   662.662659
# 2008-01-02   208.990005  214.833328    151.960007  88.083336   659.233887
# 2008-01-03   209.929993  224.083328    152.899994  91.666664   669.748718
# 2008-01-04   214.889999  226.000000    153.199997  92.800003   690.275513
# 2008-01-07   219.399994  223.666672    153.289993  88.333336   692.607056
#
#             ...  POWERGRID.NS  TATAMOTORS.NS      UPL.NS  BAJAJFINSV.NS  \
# date        ...
# 2008-01-01  ...     83.221893     146.884857  119.633331    2630.000000
# 2008-01-02  ...     83.081268     152.729584  125.983330    2629.000000
# 2008-01-03  ...     85.725021     156.370575  126.616669    2600.000000
# 2008-01-04  ...     87.750023     157.922775  129.133331    2604.699951
# 2008-01-07  ...     86.175018     154.799194  129.666672    2599.000000
#
#             ICICIBANK.NS  DIVISLAB.NS      TCS.NS    TECHM.NS  BAJFINANCE.NS  \
# date
# 2008-01-01    225.454544   482.487488  269.250000  289.937500      43.721157
# 2008-01-02    236.309097   480.225006  265.250000  287.212494      45.858635
# 2008-01-03    229.981812   480.975006  261.250000  287.000000      45.664318
# 2008-01-04    236.363632   481.250000  255.725006  286.750000      49.356327
# 2008-01-07    250.899994   474.674988  252.199997  278.750000      49.356327
#
#             BHARTIARTL.NS
# date
# 2008-01-01     450.628632
# 2008-01-02     442.832764
# 2008-01-03     434.789032
# 2008-01-04     432.107788
# 2008-01-07     427.105804
#
# [5 rows x 46 columns]

# %% [markdown]
# ### 3.3 Define Functions

# %%
def defineAutoencoder(num_stock, encoding_dim = 5, verbose=0):
    
    """
    Function for fitting an Autoencoder
    """

    # connect all layers
    input = Input(shape=(num_stock,))

    encoded = Dense(encoding_dim, kernel_regularizer=regularizers.l2(0.00001),name ='Encoder_Input')(input)

    decoded = Dense(num_stock, kernel_regularizer=regularizers.l2(0.00001), name ='Decoder_Input')(encoded)
    decoded = Activation("linear", name='Decoder_Activation_function')(decoded)

    # construct and compile AE model
    autoencoder = Model(inputs=input, outputs=decoded)
    adam = optimizers.Adam(learning_rate=0.0005)
    autoencoder.compile(optimizer=adam, loss='mean_squared_error')
    if verbose!= 0:
        autoencoder.summary()

    return autoencoder

# %%
def getReconstructionErrorsDF(df_pct_change, reconstructed_data):
    
    """
    Function for calculating the reconstruction Errors
    """
    array = []
    stocks_ranked = []
    num_columns = reconstructed_data.shape[1]
    for i in range(0, num_columns):
        diff = np.linalg.norm((df_pct_change.iloc[:, i] - reconstructed_data[:, i]))  # 2 norm difference
        array.append(float(diff))

    ranking = np.array(array).argsort()
    r = 1
    for stock_index in ranking:
        stocks_ranked.append([ r
                              ,stock_index
                              ,df_pct_change.iloc[:, stock_index].name
                              ,array[stock_index]
                              ])
        r = r + 1

    columns = ['ranking','stock_index', 'stock_name' ,'recreation_error']
    df = pd.DataFrame(stocks_ranked, columns=columns)
    df = df.set_index('stock_name')
    return df

# %% [markdown]
# ### 3.4 Get the Percentage Change of the Close Prices

# %%
col_names = df.columns.to_list()

# %%
print(col_names)
# Out:
# ['HCLTECH.NS', 'EICHERMOT.NS', 'HINDALCO.NS', 'INDUSINDBK.NS', 'GRASIM.NS', 'AXISBANK.NS', 'ONGC.NS', 'BRITANNIA.NS', 'BPCL.NS', 'RELIANCE.NS', 'GAIL.NS', 'ASIANPAINT.NS', 'ADANIPORTS.NS', 'KOTAKBANK.NS', 'TATASTEEL.NS', 'TITAN.NS', 'M&M.NS', 'SUNPHARMA.NS', 'INFY.NS', 'SHREECEM.NS', 'SBIN.NS', 'HINDUNILVR.NS', 'WIPRO.NS', 'NTPC.NS', 'BAJAJ-AUTO.NS', 'DRREDDY.NS', 'CIPLA.NS', 'NESTLEIND.NS', 'ITC.NS', 'MARUTI.NS', 'HEROMOTOCO.NS', 'LT.NS', 'ULTRACEMCO.NS', 'IOC.NS', 'HDFCBANK.NS', 'JSWSTEEL.NS', 'POWERGRID.NS', 'TATAMOTORS.NS', 'UPL.NS', 'BAJAJFINSV.NS', 'ICICIBANK.NS', 'DIVISLAB.NS', 'TCS.NS', 'TECHM.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS']

# %%
df_pct_change = df.pct_change(1).astype(float)
df_pct_change = df_pct_change.replace([np.inf, -np.inf], np.nan)
df_pct_change = df_pct_change.fillna(method='bfill')

# the percentage change function will make the first two rows equal to nan
df_pct_change = df_pct_change.tail(len(df_pct_change) - 2)
# Out:
# /var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/ipykernel_52948/2395198504.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_pct_change = df_pct_change.fillna(method='bfill')

# %%
if df_pct_change.isnull().values.any():
    print("Warning: NaN values detected in df_pct_change. Please handle them before calculating reconstruction errors.")

# %%
df_pct_change.shape
# Out:
# (3982, 46)

# %%
# remove columns where there is no change over a longer time period
df_pct_change = df_pct_change[df_pct_change.columns[((df_pct_change == 0).mean() <= 0.05)]]

# %%
df_pct_change.head()
# Out:
#             HCLTECH.NS  EICHERMOT.NS  HINDALCO.NS  INDUSINDBK.NS  GRASIM.NS  \
# date
# 2008-01-03   -0.028076      0.126829     0.007738      -0.006051  -0.015686
# 2008-01-04    0.000631     -0.058442    -0.002258       0.027397  -0.029482
# 2008-01-07   -0.002997     -0.025287    -0.008601      -0.003704  -0.008210
# 2008-01-08   -0.030380     -0.009552    -0.002740      -0.003717  -0.017936
# 2008-01-09    0.006527     -0.036790    -0.017170      -0.046269  -0.019106
#
#             AXISBANK.NS   ONGC.NS  BRITANNIA.NS   BPCL.NS  RELIANCE.NS  ...  \
# date                                                                    ...
# 2008-01-03     0.004498  0.043057      0.006186  0.040681     0.015950  ...
# 2008-01-04     0.023627  0.008553      0.001962  0.012364     0.030649  ...
# 2008-01-07     0.020987 -0.010324      0.000587 -0.048132     0.003378  ...
# 2008-01-08     0.025524 -0.004471      0.076391 -0.004340     0.017822  ...
# 2008-01-09    -0.005333 -0.004491     -0.052273 -0.014781    -0.004540  ...
#
#             POWERGRID.NS  TATAMOTORS.NS    UPL.NS  BAJAJFINSV.NS  \
# date
# 2008-01-03      0.031821       0.023839  0.005027      -0.011031
# 2008-01-04      0.023622       0.009926  0.019876       0.001808
# 2008-01-07     -0.017949      -0.019779  0.004130      -0.002188
# 2008-01-08     -0.007833      -0.010275  0.010283      -0.000039
# 2008-01-09     -0.043092      -0.015635  0.020356      -0.007349
#
#             ICICIBANK.NS  DIVISLAB.NS    TCS.NS  TECHM.NS  BAJFINANCE.NS  \
# date
# 2008-01-03     -0.026775     0.001562 -0.015080 -0.000740      -0.004237
# 2008-01-04      0.027749     0.000572 -0.021148 -0.000871       0.080851
# 2008-01-07      0.061500    -0.013662 -0.013784 -0.027899       0.000000
# 2008-01-08      0.007283    -0.001949 -0.016653  0.004484       0.061713
# 2008-01-09     -0.025288    -0.013193  0.014113  0.004464      -0.023269
#
#             BHARTIARTL.NS
# date
# 2008-01-03      -0.018164
# 2008-01-04      -0.006167
# 2008-01-07      -0.011576
# 2008-01-08       0.034501
# 2008-01-09       0.002550
#
# [5 rows x 45 columns]

# %% [markdown]
# ### 3.5 Construct the Autoencoder

# %%
# define the input parameters
hidden_layers = 5
batch_size = 500
epochs = 500
stock_selection_number = 20
num_stock = df_pct_change.shape[1]
verbose = 1

# %%
print('-' * 20 + 'Step 1 : Returns vs. recreation error (recreation_error)')
print('-' * 25 + 'Transform dataset with MinMax Scaler')
# Out:
# --------------------Step 1 : Returns vs. recreation error (recreation_error)
# -------------------------Transform dataset with MinMax Scaler

# %%
# Normalize the data
df_scaler = preprocessing.MinMaxScaler()
df_pct_change_normalised = df_scaler.fit_transform(df_pct_change)

# %%
# define autoencoder
print('-' * 25 + 'Define autoencoder model')
num_stock = len(df_pct_change.columns)
autoencoder = defineAutoencoder(num_stock=num_stock, encoding_dim=hidden_layers, verbose=verbose)
#plot_model(autoencoder, to_file='img/model_autoencoder_1.png', show_shapes=True,
#           show_layer_names=True)
# Out:
# -------------------------Define autoencoder model
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 45)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Input (Dense)           │ (None, 5)              │           230 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Input (Dense)           │ (None, 45)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Activation_function     │ (None, 45)             │             0 │
# │ (Activation)                    │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 500 (1.95 KB)
#  Trainable params: 500 (1.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train autoencoder
print('-' * 25 + 'Train autoencoder model')
autoencoder.fit(df_pct_change_normalised, df_pct_change_normalised, shuffle=False, epochs=epochs,
                batch_size=batch_size,
                verbose=verbose)
# Out:
# -------------------------Train autoencoder model
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.1890
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.1706
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.1557
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.1434
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.1326
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.1225
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.1131
# Epoch 8/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.1042
# Epoch 9/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0957
# Epoch 10/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0877
# Epoch 11/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.0801
# Epoch 12/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0729
# Epoch 13/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.0661
# Epoch 14/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0596
# Epoch 15/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0536
# Epoch 16/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0480
# Epoch 17/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0429
# Epoch 18/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0381
# Epoch 19/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0338
# Epoch 20/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0299
# Epoch 21/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.0263
# Epoch 22/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0232
# Epoch 23/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0204
# Epoch 24/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0179
# Epoch 25/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0158
# Epoch 26/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0139
# Epoch 27/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0123
# Epoch 28/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0110
# Epoch 29/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0098
# Epoch 30/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0088
# Epoch 31/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0080
# Epoch 32/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0073
# Epoch 33/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0068
# Epoch 34/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0063
# Epoch 35/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.0059
# Epoch 36/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0056
# Epoch 37/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0053
# Epoch 38/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0051
# Epoch 39/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0049
# Epoch 40/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0047
# Epoch 41/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.0046
# Epoch 42/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0045
# Epoch 43/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0044
# Epoch 44/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0044
# Epoch 45/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0043
# Epoch 46/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 0.0043
# Epoch 47/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0043
# Epoch 48/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.0042
# Epoch 49/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0042
# Epoch 50/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0042
# Epoch 51/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0042
# Epoch 52/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.0042
# Epoch 53/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0042
# Epoch 54/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0042
# Epoch 55/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0042
# Epoch 56/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.0041
# Epoch 57/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0041
# Epoch 58/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0041
# Epoch 59/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0041
# Epoch 60/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0041
# Epoch 61/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0041
# Epoch 62/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0041
# Epoch 63/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0041
# Epoch 64/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0041
# Epoch 65/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0041
# Epoch 66/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0041
# Epoch 67/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0041
# Epoch 68/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.0041
# Epoch 69/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0041
# Epoch 70/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.0041
# Epoch 71/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0041
# Epoch 72/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0041
# Epoch 73/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0041
# Epoch 74/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0041
# Epoch 75/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0041
# Epoch 76/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.0041
# Epoch 77/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0041
# Epoch 78/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0041
# Epoch 79/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.0041
# Epoch 80/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0041
# Epoch 81/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0041
# Epoch 82/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0041
# Epoch 83/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0041
# Epoch 84/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0041
# Epoch 85/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0040
# Epoch 86/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.0040
# Epoch 87/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0040
# Epoch 88/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0040
# Epoch 89/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.0040
# Epoch 90/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0040
# Epoch 91/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.0040
# Epoch 92/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0040
# Epoch 93/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0040
# Epoch 94/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.0040
# Epoch 95/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.0040
# Epoch 96/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0040
# Epoch 97/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.0040
# Epoch 98/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0040
# Epoch 99/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0040
# Epoch 100/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.0040
# Epoch 101/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0040
# Epoch 102/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0040
# Epoch 103/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0040
# Epoch 104/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0040
# Epoch 105/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.0040
# Epoch 106/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0040
# Epoch 107/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.0040
# Epoch 108/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.0040
# Epoch 109/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0040
# Epoch 110/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0040
# Epoch 111/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0040
# Epoch 112/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0040
# Epoch 113/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0040
# Epoch 114/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0040
# Epoch 115/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0040
# Epoch 116/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.0040
# Epoch 117/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0039
# Epoch 118/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0039
# Epoch 119/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0039
# Epoch 120/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0039
# Epoch 121/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0039
# Epoch 122/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0039
# Epoch 123/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0039
# Epoch 124/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0039
# Epoch 125/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.0039
# Epoch 126/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 0.0039
# Epoch 127/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0039
# Epoch 128/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.0039
# Epoch 129/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0039
# Epoch 130/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0039
# Epoch 131/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0039
# Epoch 132/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 0.0039
# Epoch 133/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0039
# Epoch 134/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0039
# Epoch 135/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0039
# Epoch 136/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0039
# Epoch 137/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0039
# Epoch 138/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0039
# Epoch 139/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0039
# Epoch 140/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0039
# Epoch 141/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0039
# Epoch 142/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0039
# Epoch 143/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0039
# Epoch 144/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0039
# Epoch 145/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0039
# Epoch 146/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0039
# Epoch 147/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0039
# Epoch 148/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0038
# Epoch 149/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0038
# Epoch 150/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0038
# Epoch 151/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0038
# Epoch 152/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0038
# Epoch 153/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0038
# Epoch 154/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0038
# Epoch 155/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: 0.0038
# Epoch 156/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0038
# Epoch 157/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0038
# Epoch 158/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0038
# Epoch 159/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0038
# Epoch 160/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0038
# Epoch 161/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0038
# Epoch 162/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0038
# Epoch 163/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0038
# Epoch 164/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0038
# Epoch 165/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0038
# Epoch 166/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0038
# Epoch 167/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0038
# Epoch 168/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0038
# Epoch 169/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0038
# Epoch 170/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0038
# Epoch 171/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0038
# Epoch 172/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0038
# Epoch 173/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0038
# Epoch 174/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.0038
# Epoch 175/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0038
# Epoch 176/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0038
# Epoch 177/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0038
# Epoch 178/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0038
# Epoch 179/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 0.0038
# Epoch 180/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0037
# Epoch 181/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0037
# Epoch 182/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.0037
# Epoch 183/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.0037
# Epoch 184/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.0037
# Epoch 185/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0037
# Epoch 186/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0037
# Epoch 187/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0037
# Epoch 188/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0037
# Epoch 189/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0037
# Epoch 190/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 0.0037
# Epoch 191/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0037
# Epoch 192/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0037
# Epoch 193/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0037
# Epoch 194/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0037
# Epoch 195/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0037
# Epoch 196/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0037
# Epoch 197/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0037
# Epoch 198/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0037
# Epoch 199/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0037
# Epoch 200/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.0037
# Epoch 201/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 0.0037
# Epoch 202/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0037
# Epoch 203/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.0037
# Epoch 204/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037
# Epoch 205/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0037
# Epoch 206/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0037
# Epoch 207/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0037
# Epoch 208/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0037
# Epoch 209/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0037
# Epoch 210/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0037
# Epoch 211/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0037
# Epoch 212/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0037
# Epoch 213/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0036
# Epoch 214/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0036
# Epoch 215/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.0036
# Epoch 216/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0036
# Epoch 217/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.0036
# Epoch 218/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0036
# Epoch 219/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0036
# Epoch 220/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0036
# Epoch 221/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0036
# Epoch 222/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0036
# Epoch 223/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0036
# Epoch 224/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0036
# Epoch 225/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.0036
# Epoch 226/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0036
# Epoch 227/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0036
# Epoch 228/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0036
# Epoch 229/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.0036
# Epoch 230/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0036
# Epoch 231/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.0036
# Epoch 232/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0036
# Epoch 233/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0036
# Epoch 234/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0036
# Epoch 235/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0036
# Epoch 236/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0036
# Epoch 237/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0036
# Epoch 238/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0036
# Epoch 239/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0036
# Epoch 240/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.0036
# Epoch 241/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.0036
# Epoch 242/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.0036
# Epoch 243/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0036
# Epoch 244/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0036
# Epoch 245/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.0036
# Epoch 246/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0036
# Epoch 247/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.0036
# Epoch 248/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0035
# Epoch 249/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0035
# Epoch 250/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0035
# Epoch 251/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.0035
# Epoch 252/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 253/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035
# Epoch 254/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.0035
# Epoch 255/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0035
# Epoch 256/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0035
# Epoch 257/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0035
# Epoch 258/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0035
# Epoch 259/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0035
# Epoch 260/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0035
# Epoch 261/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0035
# Epoch 262/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.0035
# Epoch 263/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0035
# Epoch 264/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.0035
# Epoch 265/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.0035
# Epoch 266/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0035
# Epoch 267/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.0035
# Epoch 268/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0035
# Epoch 269/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0035
# Epoch 270/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0035
# Epoch 271/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0035
# Epoch 272/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.0035
# Epoch 273/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0035
# Epoch 274/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0035
# Epoch 275/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.0035
# Epoch 276/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0035
# Epoch 277/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0035
# Epoch 278/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0035
# Epoch 279/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0035
# Epoch 280/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.0035
# Epoch 281/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0035
# Epoch 282/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0035
# Epoch 283/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0035
# Epoch 284/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0035
# Epoch 285/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0035
# Epoch 286/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0034
# Epoch 287/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0034
# Epoch 288/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0034
# Epoch 289/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0034
# Epoch 290/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0034
# Epoch 291/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0034
# Epoch 292/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0034
# Epoch 293/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0034
# Epoch 294/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0034
# Epoch 295/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0034
# Epoch 296/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0034
# Epoch 297/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0034
# Epoch 298/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.0034
# Epoch 299/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0034
# Epoch 300/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0034
# Epoch 301/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0034
# Epoch 302/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034
# Epoch 303/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034
# Epoch 304/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034
# Epoch 305/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0034
# Epoch 306/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0034
# Epoch 307/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0034
# Epoch 308/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0034
# Epoch 309/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0034
# Epoch 310/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.0034
# Epoch 311/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0034
# Epoch 312/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0034
# Epoch 313/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 0.0034
# Epoch 314/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 0.0034
# Epoch 315/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0034
# Epoch 316/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0034
# Epoch 317/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0034
# Epoch 318/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0034
# Epoch 319/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0034
# Epoch 320/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0034
# Epoch 321/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0034
# Epoch 322/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0034
# Epoch 323/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0034
# Epoch 324/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0034
# Epoch 325/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0034
# Epoch 326/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0034
# Epoch 327/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0034
# Epoch 328/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0033
# Epoch 329/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.0033
# Epoch 330/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.0033
# Epoch 331/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0033
# Epoch 332/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0033
# Epoch 333/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0033
# Epoch 334/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0033
# Epoch 335/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0033
# Epoch 336/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0033
# Epoch 337/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0033
# Epoch 338/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.0033
# Epoch 339/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0033
# Epoch 340/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0033
# Epoch 341/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0033
# Epoch 342/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0033
# Epoch 343/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0033
# Epoch 344/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0033
# Epoch 345/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0033
# Epoch 346/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0033
# Epoch 347/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0033
# Epoch 348/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0033
# Epoch 349/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0033
# Epoch 350/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0033
# Epoch 351/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.0033
# Epoch 352/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0033
# Epoch 353/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.0033
# Epoch 354/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.0033
# Epoch 355/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.0033
# Epoch 356/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0033
# Epoch 357/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0033
# Epoch 358/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033
# Epoch 359/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033
# Epoch 360/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 0.0033
# Epoch 361/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0033
# Epoch 362/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.0033
# Epoch 363/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0033
# Epoch 364/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0033
# Epoch 365/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0033
# Epoch 366/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0033
# Epoch 367/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.0033
# Epoch 368/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0033
# Epoch 369/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0033
# Epoch 370/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0033
# Epoch 371/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0033
# Epoch 372/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.0033
# Epoch 373/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0032
# Epoch 374/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0032
# Epoch 375/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.0032
# Epoch 376/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0032
# Epoch 377/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0032
# Epoch 378/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0032
# Epoch 379/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0032
# Epoch 380/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0032
# Epoch 381/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0032
# Epoch 382/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0032
# Epoch 383/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0032
# Epoch 384/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.0032
# Epoch 385/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0032
# Epoch 386/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0032
# Epoch 387/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0032
# Epoch 388/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0032
# Epoch 389/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0032
# Epoch 390/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0032
# Epoch 391/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0032
# Epoch 392/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0032
# Epoch 393/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0032
# Epoch 394/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.0032
# Epoch 395/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0032
# Epoch 396/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0032
# Epoch 397/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0032
# Epoch 398/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.0032
# Epoch 399/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0032
# Epoch 400/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.0032
# Epoch 401/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0032
# Epoch 402/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0032
# Epoch 403/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0032
# Epoch 404/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.0032
# Epoch 405/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0032
# Epoch 406/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.0032
# Epoch 407/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0032
# Epoch 408/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 0.0032
# Epoch 409/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0032
# Epoch 410/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.0032
# Epoch 411/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0032
# Epoch 412/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0032
# Epoch 413/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032
# Epoch 414/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.0032
# Epoch 415/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0032
# Epoch 416/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 0.0032
# Epoch 417/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.0032
# Epoch 418/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0032
# Epoch 419/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0032
# Epoch 420/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0032
# Epoch 421/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0032
# Epoch 422/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0032
# Epoch 423/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.0032
# Epoch 424/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0031
# Epoch 425/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0031
# Epoch 426/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0031
# Epoch 427/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 0.0031
# Epoch 428/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 0.0031
# Epoch 429/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0031
# Epoch 430/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0031
# Epoch 431/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 0.0031
# Epoch 432/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 0.0031
# Epoch 433/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0031
# Epoch 434/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.0031
# Epoch 435/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0031
# Epoch 436/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 0.0031
# Epoch 437/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0031
# Epoch 438/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 0.0031
# Epoch 439/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0031
# Epoch 440/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0031
# Epoch 441/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0031
# Epoch 442/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0031
# Epoch 443/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.0031
# Epoch 444/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0031
# Epoch 445/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0031
# Epoch 446/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0031
# Epoch 447/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0031
# Epoch 448/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0031
# Epoch 449/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0031
# Epoch 450/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0031
# Epoch 451/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0031
# Epoch 452/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0031
# Epoch 453/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0031
# Epoch 454/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0031
# Epoch 455/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 456/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 457/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 458/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0031
# Epoch 459/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0031
# Epoch 460/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0031
# Epoch 461/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.0031
# Epoch 462/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0031
# Epoch 463/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0031
# Epoch 464/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0031
# Epoch 465/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0031
# Epoch 466/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0031
# Epoch 467/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0031
# Epoch 468/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0031
# Epoch 469/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0031
# Epoch 470/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0031
# Epoch 471/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0031
# Epoch 472/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0031
# Epoch 473/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0031
# Epoch 474/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.0031
# Epoch 475/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0031
# Epoch 476/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0031
# Epoch 477/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0031
# Epoch 478/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0031
# Epoch 479/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.0031
# Epoch 480/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0031
# Epoch 481/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0031
# Epoch 482/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0031
# Epoch 483/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0030
# Epoch 484/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0030
# Epoch 485/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0030
# Epoch 486/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0030
# Epoch 487/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 0.0030
# Epoch 488/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0030
# Epoch 489/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0030
# Epoch 490/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0030
# Epoch 491/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0030
# Epoch 492/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 0.0030
# Epoch 493/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0030
# Epoch 494/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0030
# Epoch 495/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.0030
# Epoch 496/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030
# Epoch 497/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030
# Epoch 498/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.0030
# Epoch 499/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0030
# Epoch 500/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.0030

# %%
# predict autoencoder
print('-' * 25 + 'Predict autoencoder model')
reconstruct = autoencoder.predict(df_pct_change_normalised)
# Out:
# -------------------------Predict autoencoder model
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step

# %%
# Inverse transform dataset with MinMax Scaler
print('-' * 25 + 'Inverse transform dataset with MinMax Scaler')
reconstruct_real = df_scaler.inverse_transform(reconstruct)
df_reconstruct_real = pd.DataFrame(data=reconstruct_real, columns=df_pct_change.columns)
# Out:
# -------------------------Inverse transform dataset with MinMax Scaler

# %%
print('-' * 25 + 'Calculate L2 norm as reconstruction loss metric')
df_recreation_error = getReconstructionErrorsDF(df_pct_change=df_pct_change,
                                                reconstructed_data=reconstruct_real)
# Out:
# -------------------------Calculate L2 norm as reconstruction loss metric

# %%
df_recreation_error
# Out:
#                ranking  stock_index  recreation_error
# stock_name
# ITC.NS               1           27          0.849437
# NTPC.NS              2           23          0.858446
# HDFCBANK.NS          3           33          0.859710
# HINDUNILVR.NS        4           21          0.859882
# CIPLA.NS             5           26          0.905599
# GRASIM.NS            6            4          0.918263
# LT.NS                7           30          0.920663
# ASIANPAINT.NS        8           11          0.926349
# MARUTI.NS            9           28          0.952041
# RELIANCE.NS         10            9          0.955993
# POWERGRID.NS        11           35          0.959318
# SUNPHARMA.NS        12           17          0.963297
# WIPRO.NS            13           22          0.993836
# TCS.NS              14           41          0.999129
# DRREDDY.NS          15           25          1.017615
# INFY.NS             16           18          1.024894
# GAIL.NS             17           10          1.041445
# SBIN.NS             18           20          1.042278
# ICICIBANK.NS        19           39          1.054721
# HEROMOTOCO.NS       20           29          1.054911
# KOTAKBANK.NS        21           13          1.060693
# M&M.NS              22           16          1.061100
# BRITANNIA.NS        23            7          1.099698
# TATASTEEL.NS        24           14          1.100994
# TITAN.NS            25           15          1.102407
# DIVISLAB.NS         26           40          1.107463
# ULTRACEMCO.NS       27           31          1.108041
# UPL.NS              28           37          1.119853
# BPCL.NS             29            8          1.139978
# AXISBANK.NS         30            5          1.146787
# HINDALCO.NS         31            2          1.149897
# IOC.NS              32           32          1.165423
# HCLTECH.NS          33            0          1.168242
# ONGC.NS             34            6          1.185802
# BAJAJ-AUTO.NS       35           24          1.192728
# TECHM.NS            36           42          1.196883
# BHARTIARTL.NS       37           44          1.223521
# SHREECEM.NS         38           19          1.259713
# TATAMOTORS.NS       39           36          1.289857
# JSWSTEEL.NS         40           34          1.299322
# BAJFINANCE.NS       41           43          1.360239
# INDUSINDBK.NS       42            3          1.381611
# ADANIPORTS.NS       43           12          1.406165
# EICHERMOT.NS        44            1          1.427722
# BAJAJFINSV.NS       45           38          2.946354

# %%
filtered_stocks = df_recreation_error.head(stock_selection_number).index

# %%
filtered_stocks
# Out:
# Index(['ITC.NS', 'NTPC.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'CIPLA.NS',
#        'GRASIM.NS', 'LT.NS', 'ASIANPAINT.NS', 'MARUTI.NS', 'RELIANCE.NS',
#        'POWERGRID.NS', 'SUNPHARMA.NS', 'WIPRO.NS', 'TCS.NS', 'DRREDDY.NS',
#        'INFY.NS', 'GAIL.NS', 'SBIN.NS', 'ICICIBANK.NS', 'HEROMOTOCO.NS'],
#       dtype='object', name='stock_name')

# %%
# store the list of selected stocks
# %store filtered_stocks
# Out:
# Stored 'filtered_stocks' (Index)

# %%
pip install pickleshare
# Out:
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.7.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %store
# Out:
# Stored variables and their in-db values:
# df_close_full_stocks             ->             date   HCLTECH.NS  EICHERMOT.NS  HINDA
# filtered_stocks                  -> Index(['ITC.NS', 'NTPC.NS', 'HDFCBANK.NS', 'HINDUN
